# %%
from util.greedy_solver import GreedyFJSSPSolver, GreedyFJSSPWSolver

# %%
from util.benchmark_parser import WorkerBenchmarkParser
parser = WorkerBenchmarkParser()
encoding = parser.parse_benchmark(r'instances/fjssp-w/3_DPpaulli_1_workers.fjs')
# Out:
# Total operations for job 1: 15
# 	Options for operation 1 (index 0): 1
# 		Option 1: Machine 1
# 			Worker options: 7
# 				(Worker 1, duration 45)
# 				(Worker 2, duration 38)
# 				(Worker 3, duration 42)
# 				(Worker 4, duration 40)
# 				(Worker 5, duration 43)
# 				(Worker 6, duration 42)
# 				(Worker 7, duration 44)
# 	Options for operation 2 (index 1): 1
# 		Option 1: Machine 3
# 			Worker options: 2
# 				(Worker 2, duration 62)
# 				(Worker 5, duration 66)
# 	Options for operation 3 (index 2): 1
# 		Option 1: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 22)
# 				(Worker 2, duration 21)
# 				(Worker 3, duration 21)
# 				(Worker 4, duration 24)
# 				(Worker 5, duration 21)
# 				(Worker 6, duration 21)
# 	Options for operation 4 (index 3): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 16)
# 				(Worker 2, duration 15)
# 				(Worker 3, duration 17)
# 				(Worker 4, duration 15)
# 				(Worker 5, duration 15)
# 				(Worker 7, duration 17)
# 	Options for operation 5 (index 4): 3
# 		Option 1: Machine 1
# 			Worker options: 4
# 				(Worker 1, duration 93)
# 				(Worker 4, duration 102)
# 				(Worker 5, duration 91)
# 				(Worker 7, duration 95)
# 		Option 2: Machine 3
# 			Worker options: 3
# 				(Worker 1, duration 97)
# 				(Worker 2, duration 92)
# 				(Worker 4, duration 102)
# 		Option 3: Machine 5
# 			Worker options: 5
# 				(Worker 1, duration 105)
# 				(Worker 2, duration 89)
# 				(Worker 3, duration 96)
# 				(Worker 4, duration 92)
# 				(Worker 7, duration 91)
# 	Options for operation 6 (index 5): 1
# 		Option 1: Machine 5
# 			Worker options: 1
# 				(Worker 6, duration 23)
# 	Options for operation 7 (index 6): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 1, duration 63)
# 				(Worker 3, duration 57)
# 				(Worker 4, duration 66)
# 	Options for operation 8 (index 7): 1
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 1, duration 32)
# 				(Worker 2, duration 31)
# 				(Worker 3, duration 29)
# 	Options for operation 9 (index 8): 1
# 		Option 1: Machine 3
# 			Worker options: 5
# 				(Worker 1, duration 76)
# 				(Worker 2, duration 77)
# 				(Worker 5, duration 91)
# 				(Worker 6, duration 86)
# 				(Worker 7, duration 81)
# 	Options for operation 10 (index 9): 1
# 		Option 1: Machine 5
# 			Worker options: 1
# 				(Worker 1, duration 21)
# 	Options for operation 11 (index 10): 1
# 		Option 1: Machine 5
# 			Worker options: 4
# 				(Worker 2, duration 66)
# 				(Worker 4, duration 63)
# 				(Worker 6, duration 61)
# 				(Worker 7, duration 72)
# 	Options for operation 12 (index 11): 1
# 		Option 1: Machine 3
# 			Worker options: 4
# 				(Worker 3, duration 31)
# 				(Worker 5, duration 30)
# 				(Worker 6, duration 31)
# 				(Worker 7, duration 30)
# 	Options for operation 13 (index 12): 2
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 3, duration 11)
# 				(Worker 4, duration 10)
# 				(Worker 5, duration 11)
# 				(Worker 6, duration 12)
# 				(Worker 7, duration 11)
# 		Option 2: Machine 5
# 			Worker options: 5
# 				(Worker 2, duration 12)
# 				(Worker 3, duration 10)
# 				(Worker 4, duration 11)
# 				(Worker 5, duration 12)
# 				(Worker 6, duration 12)
# 	Options for operation 14 (index 13): 1
# 		Option 1: Machine 3
# 			Worker options: 4
# 				(Worker 2, duration 61)
# 				(Worker 3, duration 68)
# 				(Worker 4, duration 59)
# 				(Worker 6, duration 58)
# 	Options for operation 15 (index 14): 1
# 		Option 1: Machine 1
# 			Worker options: 4
# 				(Worker 3, duration 99)
# 				(Worker 5, duration 100)
# 				(Worker 6, duration 90)
# 				(Worker 7, duration 90)
# Total operations for job 2: 20
# 	Options for operation 1 (index 15): 2
# 		Option 1: Machine 1
# 			Worker options: 6
# 				(Worker 1, duration 43)
# 				(Worker 2, duration 41)
# 				(Worker 4, duration 40)
# 				(Worker 5, duration 37)
# 				(Worker 6, duration 41)
# 				(Worker 7, duration 45)
# 		Option 2: Machine 3
# 			Worker options: 2
# 				(Worker 6, duration 39)
# 				(Worker 7, duration 45)
# 	Options for operation 2 (index 16): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 82)
# 				(Worker 2, duration 96)
# 				(Worker 3, duration 94)
# 				(Worker 4, duration 90)
# 				(Worker 6, duration 85)
# 	Options for operation 3 (index 17): 1
# 		Option 1: Machine 1
# 			Worker options: 1
# 				(Worker 1, duration 68)
# 	Options for operation 4 (index 18): 1
# 		Option 1: Machine 1
# 			Worker options: 6
# 				(Worker 2, duration 45)
# 				(Worker 3, duration 43)
# 				(Worker 4, duration 41)
# 				(Worker 5, duration 43)
# 				(Worker 6, duration 47)
# 				(Worker 7, duration 45)
# 	Options for operation 5 (index 19): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 83)
# 				(Worker 2, duration 96)
# 				(Worker 3, duration 100)
# 				(Worker 4, duration 87)
# 				(Worker 5, duration 82)
# 				(Worker 7, duration 84)
# 	Options for operation 6 (index 20): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 72)
# 				(Worker 3, duration 71)
# 				(Worker 4, duration 79)
# 				(Worker 5, duration 69)
# 				(Worker 6, duration 67)
# 				(Worker 7, duration 69)
# 	Options for operation 7 (index 21): 1
# 		Option 1: Machine 5
# 			Worker options: 1
# 				(Worker 5, duration 33)
# 	Options for operation 8 (index 22): 1
# 		Option 1: Machine 4
# 			Worker options: 7
# 				(Worker 1, duration 95)
# 				(Worker 2, duration 100)
# 				(Worker 3, duration 105)
# 				(Worker 4, duration 100)
# 				(Worker 5, duration 98)
# 				(Worker 6, duration 97)
# 				(Worker 7, duration 97)
# 	Options for operation 9 (index 23): 1
# 		Option 1: Machine 5
# 			Worker options: 5
# 				(Worker 3, duration 11)
# 				(Worker 4, duration 12)
# 				(Worker 5, duration 12)
# 				(Worker 6, duration 11)
# 				(Worker 7, duration 11)
# 	Options for operation 10 (index 24): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 2, duration 22)
# 				(Worker 3, duration 21)
# 				(Worker 4, duration 18)
# 				(Worker 5, duration 18)
# 				(Worker 6, duration 22)
# 				(Worker 7, duration 21)
# 	Options for operation 11 (index 25): 1
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 2, duration 86)
# 	Options for operation 12 (index 26): 2
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 19)
# 				(Worker 2, duration 23)
# 				(Worker 3, duration 20)
# 				(Worker 4, duration 21)
# 				(Worker 5, duration 20)
# 				(Worker 6, duration 21)
# 				(Worker 7, duration 22)
# 		Option 2: Machine 4
# 			Worker options: 1
# 				(Worker 2, duration 19)
# 	Options for operation 13 (index 27): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 2, duration 75)
# 	Options for operation 14 (index 28): 1
# 		Option 1: Machine 5
# 			Worker options: 5
# 				(Worker 3, duration 40)
# 				(Worker 4, duration 39)
# 				(Worker 5, duration 35)
# 				(Worker 6, duration 35)
# 				(Worker 7, duration 34)
# 	Options for operation 15 (index 29): 1
# 		Option 1: Machine 5
# 			Worker options: 4
# 				(Worker 1, duration 66)
# 				(Worker 3, duration 74)
# 				(Worker 5, duration 65)
# 				(Worker 6, duration 68)
# 	Options for operation 16 (index 30): 2
# 		Option 1: Machine 1
# 			Worker options: 7
# 				(Worker 1, duration 44)
# 				(Worker 2, duration 45)
# 				(Worker 3, duration 47)
# 				(Worker 4, duration 48)
# 				(Worker 5, duration 51)
# 				(Worker 6, duration 46)
# 				(Worker 7, duration 48)
# 		Option 2: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 51)
# 				(Worker 2, duration 49)
# 				(Worker 3, duration 51)
# 				(Worker 4, duration 50)
# 				(Worker 5, duration 52)
# 				(Worker 6, duration 47)
# 				(Worker 7, duration 47)
# 	Options for operation 17 (index 31): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 1, duration 53)
# 				(Worker 3, duration 59)
# 				(Worker 5, duration 60)
# 				(Worker 6, duration 52)
# 				(Worker 7, duration 59)
# 	Options for operation 18 (index 32): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 2, duration 35)
# 				(Worker 6, duration 41)
# 				(Worker 7, duration 36)
# 	Options for operation 19 (index 33): 2
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 50)
# 				(Worker 2, duration 45)
# 				(Worker 3, duration 45)
# 				(Worker 4, duration 51)
# 				(Worker 5, duration 51)
# 				(Worker 6, duration 46)
# 				(Worker 7, duration 51)
# 		Option 2: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 45)
# 				(Worker 2, duration 49)
# 				(Worker 3, duration 49)
# 				(Worker 5, duration 47)
# 				(Worker 6, duration 47)
# 				(Worker 7, duration 52)
# 	Options for operation 20 (index 34): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 2, duration 71)
# Total operations for job 3: 23
# 	Options for operation 1 (index 35): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 2, duration 71)
# 				(Worker 3, duration 75)
# 				(Worker 4, duration 76)
# 				(Worker 5, duration 73)
# 				(Worker 6, duration 69)
# 				(Worker 7, duration 73)
# 	Options for operation 2 (index 36): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 1, duration 78)
# 				(Worker 5, duration 87)
# 	Options for operation 3 (index 37): 2
# 		Option 1: Machine 3
# 			Worker options: 2
# 				(Worker 5, duration 91)
# 				(Worker 6, duration 81)
# 		Option 2: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 91)
# 				(Worker 2, duration 87)
# 				(Worker 3, duration 83)
# 				(Worker 4, duration 84)
# 				(Worker 5, duration 88)
# 				(Worker 6, duration 83)
# 	Options for operation 4 (index 38): 1
# 		Option 1: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 39)
# 				(Worker 2, duration 35)
# 				(Worker 3, duration 36)
# 				(Worker 5, duration 41)
# 				(Worker 6, duration 41)
# 				(Worker 7, duration 40)
# 	Options for operation 5 (index 39): 1
# 		Option 1: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 90)
# 				(Worker 2, duration 103)
# 				(Worker 3, duration 93)
# 				(Worker 4, duration 99)
# 				(Worker 5, duration 100)
# 				(Worker 6, duration 90)
# 				(Worker 7, duration 104)
# 	Options for operation 6 (index 40): 1
# 		Option 1: Machine 5
# 			Worker options: 2
# 				(Worker 6, duration 65)
# 				(Worker 7, duration 72)
# 	Options for operation 7 (index 41): 1
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 1, duration 25)
# 				(Worker 2, duration 22)
# 				(Worker 3, duration 26)
# 	Options for operation 8 (index 42): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 96)
# 				(Worker 2, duration 86)
# 				(Worker 3, duration 86)
# 				(Worker 5, duration 94)
# 				(Worker 6, duration 95)
# 	Options for operation 9 (index 43): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 70)
# 				(Worker 2, duration 71)
# 				(Worker 3, duration 66)
# 				(Worker 4, duration 76)
# 				(Worker 5, duration 76)
# 				(Worker 7, duration 67)
# 	Options for operation 10 (index 44): 1
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 5, duration 40)
# 	Options for operation 11 (index 45): 1
# 		Option 1: Machine 3
# 			Worker options: 2
# 				(Worker 2, duration 60)
# 				(Worker 6, duration 67)
# 	Options for operation 12 (index 46): 2
# 		Option 1: Machine 1
# 			Worker options: 4
# 				(Worker 1, duration 57)
# 				(Worker 2, duration 56)
# 				(Worker 5, duration 48)
# 				(Worker 7, duration 55)
# 		Option 2: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 50)
# 				(Worker 2, duration 53)
# 				(Worker 3, duration 55)
# 				(Worker 4, duration 51)
# 				(Worker 5, duration 56)
# 				(Worker 6, duration 53)
# 				(Worker 7, duration 49)
# 	Options for operation 13 (index 47): 1
# 		Option 1: Machine 1
# 			Worker options: 1
# 				(Worker 6, duration 33)
# 	Options for operation 14 (index 48): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 2, duration 92)
# 				(Worker 4, duration 100)
# 				(Worker 5, duration 102)
# 				(Worker 6, duration 93)
# 				(Worker 7, duration 102)
# 	Options for operation 15 (index 49): 1
# 		Option 1: Machine 1
# 			Worker options: 6
# 				(Worker 1, duration 31)
# 				(Worker 2, duration 33)
# 				(Worker 3, duration 33)
# 				(Worker 4, duration 31)
# 				(Worker 6, duration 30)
# 				(Worker 7, duration 33)
# 	Options for operation 16 (index 50): 1
# 		Option 1: Machine 5
# 			Worker options: 1
# 				(Worker 5, duration 54)
# 	Options for operation 17 (index 51): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 1, duration 64)
# 	Options for operation 18 (index 52): 1
# 		Option 1: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 67)
# 				(Worker 2, duration 63)
# 				(Worker 3, duration 62)
# 				(Worker 4, duration 64)
# 				(Worker 5, duration 64)
# 				(Worker 6, duration 56)
# 				(Worker 7, duration 61)
# 	Options for operation 19 (index 53): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 1, duration 54)
# 				(Worker 4, duration 57)
# 				(Worker 6, duration 59)
# 	Options for operation 20 (index 54): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 6, duration 26)
# 	Options for operation 21 (index 55): 1
# 		Option 1: Machine 4
# 			Worker options: 2
# 				(Worker 1, duration 18)
# 				(Worker 5, duration 18)
# 	Options for operation 22 (index 56): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 33)
# 				(Worker 3, duration 32)
# 				(Worker 4, duration 34)
# 				(Worker 5, duration 37)
# 				(Worker 6, duration 32)
# 				(Worker 7, duration 38)
# 	Options for operation 23 (index 57): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 2, duration 66)
# 				(Worker 7, duration 66)
# Total operations for job 4: 18
# 	Options for operation 1 (index 58): 2
# 		Option 1: Machine 3
# 			Worker options: 1
# 				(Worker 7, duration 83)
# 		Option 2: Machine 4
# 			Worker options: 3
# 				(Worker 3, duration 80)
# 				(Worker 4, duration 78)
# 				(Worker 6, duration 80)
# 	Options for operation 2 (index 59): 1
# 		Option 1: Machine 3
# 			Worker options: 2
# 				(Worker 3, duration 69)
# 				(Worker 5, duration 77)
# 	Options for operation 3 (index 60): 1
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 59)
# 				(Worker 2, duration 59)
# 				(Worker 3, duration 60)
# 				(Worker 4, duration 71)
# 				(Worker 5, duration 62)
# 				(Worker 6, duration 66)
# 				(Worker 7, duration 70)
# 	Options for operation 4 (index 61): 1
# 		Option 1: Machine 1
# 			Worker options: 4
# 				(Worker 1, duration 42)
# 				(Worker 3, duration 41)
# 				(Worker 4, duration 48)
# 				(Worker 7, duration 48)
# 	Options for operation 5 (index 62): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 2, duration 56)
# 				(Worker 3, duration 52)
# 				(Worker 5, duration 58)
# 	Options for operation 6 (index 63): 1
# 		Option 1: Machine 3
# 			Worker options: 3
# 				(Worker 3, duration 63)
# 				(Worker 5, duration 54)
# 				(Worker 6, duration 62)
# 	Options for operation 7 (index 64): 1
# 		Option 1: Machine 3
# 			Worker options: 2
# 				(Worker 3, duration 72)
# 				(Worker 7, duration 64)
# 	Options for operation 8 (index 65): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 92)
# 				(Worker 2, duration 90)
# 				(Worker 3, duration 102)
# 				(Worker 4, duration 91)
# 				(Worker 5, duration 97)
# 				(Worker 6, duration 86)
# 	Options for operation 9 (index 66): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 2, duration 28)
# 				(Worker 3, duration 28)
# 				(Worker 5, duration 29)
# 				(Worker 6, duration 26)
# 				(Worker 7, duration 30)
# 	Options for operation 10 (index 67): 1
# 		Option 1: Machine 3
# 			Worker options: 5
# 				(Worker 1, duration 63)
# 				(Worker 2, duration 65)
# 				(Worker 3, duration 66)
# 				(Worker 4, duration 57)
# 				(Worker 5, duration 66)
# 	Options for operation 11 (index 68): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 1, duration 17)
# 				(Worker 2, duration 18)
# 				(Worker 4, duration 17)
# 				(Worker 5, duration 16)
# 				(Worker 7, duration 18)
# 	Options for operation 12 (index 69): 1
# 		Option 1: Machine 3
# 			Worker options: 4
# 				(Worker 3, duration 59)
# 				(Worker 4, duration 56)
# 				(Worker 5, duration 66)
# 				(Worker 7, duration 62)
# 	Options for operation 13 (index 70): 1
# 		Option 1: Machine 2
# 			Worker options: 4
# 				(Worker 3, duration 31)
# 				(Worker 5, duration 35)
# 				(Worker 6, duration 37)
# 				(Worker 7, duration 37)
# 	Options for operation 14 (index 71): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 5, duration 101)
# 				(Worker 6, duration 88)
# 				(Worker 7, duration 103)
# 	Options for operation 15 (index 72): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 1, duration 33)
# 				(Worker 3, duration 29)
# 				(Worker 4, duration 33)
# 				(Worker 5, duration 33)
# 				(Worker 6, duration 32)
# 	Options for operation 16 (index 73): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 80)
# 				(Worker 2, duration 90)
# 				(Worker 3, duration 87)
# 				(Worker 4, duration 83)
# 				(Worker 6, duration 90)
# 				(Worker 7, duration 83)
# 	Options for operation 17 (index 74): 1
# 		Option 1: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 37)
# 				(Worker 2, duration 44)
# 				(Worker 4, duration 42)
# 				(Worker 5, duration 39)
# 				(Worker 6, duration 40)
# 				(Worker 7, duration 38)
# 	Options for operation 18 (index 75): 2
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 3, duration 60)
# 				(Worker 6, duration 62)
# 		Option 2: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 63)
# 				(Worker 2, duration 60)
# 				(Worker 4, duration 63)
# 				(Worker 5, duration 57)
# 				(Worker 7, duration 69)
# Total operations for job 5: 21
# 	Options for operation 1 (index 76): 1
# 		Option 1: Machine 2
# 			Worker options: 4
# 				(Worker 2, duration 95)
# 				(Worker 4, duration 93)
# 				(Worker 6, duration 92)
# 				(Worker 7, duration 103)
# 	Options for operation 2 (index 77): 1
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 1, duration 66)
# 				(Worker 5, duration 74)
# 				(Worker 6, duration 74)
# 	Options for operation 3 (index 78): 1
# 		Option 1: Machine 4
# 			Worker options: 4
# 				(Worker 1, duration 94)
# 				(Worker 5, duration 88)
# 				(Worker 6, duration 84)
# 				(Worker 7, duration 98)
# 	Options for operation 4 (index 79): 2
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 2, duration 39)
# 				(Worker 5, duration 40)
# 				(Worker 6, duration 45)
# 		Option 2: Machine 4
# 			Worker options: 2
# 				(Worker 2, duration 43)
# 				(Worker 5, duration 46)
# 	Options for operation 5 (index 80): 1
# 		Option 1: Machine 3
# 			Worker options: 7
# 				(Worker 1, duration 35)
# 				(Worker 2, duration 34)
# 				(Worker 3, duration 31)
# 				(Worker 4, duration 29)
# 				(Worker 5, duration 31)
# 				(Worker 6, duration 32)
# 				(Worker 7, duration 32)
# 	Options for operation 6 (index 81): 2
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 7, duration 58)
# 		Option 2: Machine 5
# 			Worker options: 4
# 				(Worker 1, duration 58)
# 				(Worker 2, duration 58)
# 				(Worker 3, duration 52)
# 				(Worker 5, duration 57)
# 	Options for operation 7 (index 82): 2
# 		Option 1: Machine 3
# 			Worker options: 7
# 				(Worker 1, duration 101)
# 				(Worker 2, duration 99)
# 				(Worker 3, duration 86)
# 				(Worker 4, duration 96)
# 				(Worker 5, duration 87)
# 				(Worker 6, duration 97)
# 				(Worker 7, duration 85)
# 		Option 2: Machine 4
# 			Worker options: 2
# 				(Worker 2, duration 88)
# 				(Worker 7, duration 99)
# 	Options for operation 8 (index 83): 1
# 		Option 1: Machine 2
# 			Worker options: 4
# 				(Worker 2, duration 37)
# 				(Worker 4, duration 38)
# 				(Worker 6, duration 41)
# 				(Worker 7, duration 42)
# 	Options for operation 9 (index 84): 1
# 		Option 1: Machine 3
# 			Worker options: 1
# 				(Worker 2, duration 92)
# 	Options for operation 10 (index 85): 1
# 		Option 1: Machine 3
# 			Worker options: 4
# 				(Worker 1, duration 37)
# 				(Worker 2, duration 39)
# 				(Worker 4, duration 35)
# 				(Worker 6, duration 35)
# 	Options for operation 11 (index 86): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 102)
# 				(Worker 2, duration 87)
# 				(Worker 3, duration 86)
# 				(Worker 4, duration 101)
# 				(Worker 6, duration 92)
# 	Options for operation 12 (index 87): 1
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 65)
# 				(Worker 2, duration 64)
# 				(Worker 3, duration 66)
# 				(Worker 4, duration 63)
# 				(Worker 5, duration 62)
# 				(Worker 6, duration 58)
# 				(Worker 7, duration 61)
# 	Options for operation 13 (index 88): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 97)
# 				(Worker 2, duration 108)
# 				(Worker 3, duration 102)
# 				(Worker 4, duration 104)
# 				(Worker 6, duration 96)
# 				(Worker 7, duration 91)
# 	Options for operation 14 (index 89): 1
# 		Option 1: Machine 5
# 			Worker options: 4
# 				(Worker 2, duration 44)
# 				(Worker 4, duration 41)
# 				(Worker 5, duration 45)
# 				(Worker 6, duration 48)
# 	Options for operation 15 (index 90): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 2, duration 26)
# 	Options for operation 16 (index 91): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 2, duration 54)
# 				(Worker 3, duration 65)
# 				(Worker 5, duration 56)
# 				(Worker 6, duration 61)
# 				(Worker 7, duration 57)
# 	Options for operation 17 (index 92): 1
# 		Option 1: Machine 4
# 			Worker options: 3
# 				(Worker 3, duration 102)
# 				(Worker 6, duration 105)
# 				(Worker 7, duration 106)
# 	Options for operation 18 (index 93): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 1, duration 72)
# 	Options for operation 19 (index 94): 1
# 		Option 1: Machine 2
# 			Worker options: 2
# 				(Worker 5, duration 56)
# 				(Worker 6, duration 61)
# 	Options for operation 20 (index 95): 1
# 		Option 1: Machine 5
# 			Worker options: 4
# 				(Worker 1, duration 106)
# 				(Worker 2, duration 92)
# 				(Worker 4, duration 105)
# 				(Worker 5, duration 101)
# 	Options for operation 21 (index 96): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 1, duration 41)
# 				(Worker 2, duration 38)
# 				(Worker 3, duration 45)
# 				(Worker 4, duration 41)
# 				(Worker 7, duration 43)
# Total operations for job 6: 15
# 	Options for operation 1 (index 97): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 99)
# 				(Worker 3, duration 91)
# 				(Worker 4, duration 108)
# 				(Worker 5, duration 104)
# 				(Worker 6, duration 97)
# 				(Worker 7, duration 96)
# 	Options for operation 2 (index 98): 2
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 1, duration 73)
# 		Option 2: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 70)
# 				(Worker 2, duration 67)
# 				(Worker 3, duration 67)
# 				(Worker 4, duration 74)
# 				(Worker 5, duration 63)
# 				(Worker 6, duration 69)
# 				(Worker 7, duration 73)
# 	Options for operation 3 (index 99): 2
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 77)
# 				(Worker 2, duration 78)
# 				(Worker 4, duration 87)
# 				(Worker 5, duration 79)
# 				(Worker 6, duration 90)
# 				(Worker 7, duration 86)
# 		Option 2: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 81)
# 				(Worker 2, duration 76)
# 				(Worker 3, duration 90)
# 				(Worker 4, duration 79)
# 				(Worker 5, duration 89)
# 				(Worker 6, duration 77)
# 	Options for operation 4 (index 100): 2
# 		Option 1: Machine 3
# 			Worker options: 3
# 				(Worker 2, duration 67)
# 				(Worker 3, duration 69)
# 				(Worker 5, duration 71)
# 		Option 2: Machine 5
# 			Worker options: 3
# 				(Worker 1, duration 73)
# 				(Worker 5, duration 66)
# 				(Worker 7, duration 72)
# 	Options for operation 5 (index 101): 1
# 		Option 1: Machine 5
# 			Worker options: 2
# 				(Worker 1, duration 18)
# 				(Worker 5, duration 18)
# 	Options for operation 6 (index 102): 1
# 		Option 1: Machine 5
# 			Worker options: 3
# 				(Worker 1, duration 26)
# 				(Worker 2, duration 28)
# 				(Worker 3, duration 25)
# 	Options for operation 7 (index 103): 1
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 3, duration 30)
# 				(Worker 4, duration 27)
# 				(Worker 7, duration 30)
# 	Options for operation 8 (index 104): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 20)
# 				(Worker 2, duration 20)
# 				(Worker 3, duration 19)
# 				(Worker 4, duration 19)
# 				(Worker 5, duration 18)
# 				(Worker 7, duration 20)
# 	Options for operation 9 (index 105): 1
# 		Option 1: Machine 3
# 			Worker options: 7
# 				(Worker 1, duration 104)
# 				(Worker 2, duration 97)
# 				(Worker 3, duration 99)
# 				(Worker 4, duration 99)
# 				(Worker 5, duration 100)
# 				(Worker 6, duration 101)
# 				(Worker 7, duration 92)
# 	Options for operation 10 (index 106): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 3, duration 94)
# 				(Worker 4, duration 87)
# 				(Worker 5, duration 88)
# 				(Worker 6, duration 85)
# 				(Worker 7, duration 82)
# 	Options for operation 11 (index 107): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 6, duration 61)
# 				(Worker 7, duration 66)
# 	Options for operation 12 (index 108): 1
# 		Option 1: Machine 3
# 			Worker options: 3
# 				(Worker 1, duration 16)
# 				(Worker 2, duration 17)
# 				(Worker 7, duration 14)
# 	Options for operation 13 (index 109): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 2, duration 78)
# 				(Worker 3, duration 90)
# 				(Worker 4, duration 88)
# 				(Worker 5, duration 81)
# 				(Worker 6, duration 92)
# 	Options for operation 14 (index 110): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 1, duration 39)
# 				(Worker 2, duration 33)
# 				(Worker 3, duration 35)
# 				(Worker 4, duration 38)
# 				(Worker 5, duration 33)
# 	Options for operation 15 (index 111): 1
# 		Option 1: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 66)
# 				(Worker 2, duration 70)
# 				(Worker 3, duration 68)
# 				(Worker 4, duration 73)
# 				(Worker 6, duration 72)
# 				(Worker 7, duration 74)
# Total operations for job 7: 17
# 	Options for operation 1 (index 112): 1
# 		Option 1: Machine 3
# 			Worker options: 1
# 				(Worker 1, duration 40)
# 	Options for operation 2 (index 113): 1
# 		Option 1: Machine 3
# 			Worker options: 3
# 				(Worker 3, duration 91)
# 				(Worker 4, duration 103)
# 				(Worker 7, duration 103)
# 	Options for operation 3 (index 114): 1
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 1, duration 21)
# 				(Worker 3, duration 23)
# 				(Worker 5, duration 21)
# 	Options for operation 4 (index 115): 1
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 32)
# 				(Worker 2, duration 30)
# 				(Worker 3, duration 36)
# 				(Worker 4, duration 32)
# 				(Worker 5, duration 34)
# 				(Worker 6, duration 35)
# 				(Worker 7, duration 30)
# 	Options for operation 5 (index 116): 1
# 		Option 1: Machine 1
# 			Worker options: 7
# 				(Worker 1, duration 91)
# 				(Worker 2, duration 85)
# 				(Worker 3, duration 93)
# 				(Worker 4, duration 100)
# 				(Worker 5, duration 83)
# 				(Worker 6, duration 94)
# 				(Worker 7, duration 85)
# 	Options for operation 6 (index 117): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 2, duration 71)
# 				(Worker 3, duration 72)
# 				(Worker 4, duration 67)
# 				(Worker 5, duration 78)
# 				(Worker 6, duration 79)
# 				(Worker 7, duration 67)
# 	Options for operation 7 (index 118): 1
# 		Option 1: Machine 2
# 			Worker options: 4
# 				(Worker 1, duration 90)
# 				(Worker 4, duration 90)
# 				(Worker 6, duration 84)
# 				(Worker 7, duration 84)
# 	Options for operation 8 (index 119): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 2, duration 53)
# 				(Worker 4, duration 48)
# 	Options for operation 9 (index 120): 2
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 32)
# 				(Worker 2, duration 31)
# 				(Worker 3, duration 36)
# 				(Worker 4, duration 32)
# 				(Worker 6, duration 34)
# 				(Worker 7, duration 32)
# 		Option 2: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 34)
# 				(Worker 3, duration 36)
# 				(Worker 4, duration 33)
# 				(Worker 5, duration 35)
# 				(Worker 6, duration 35)
# 				(Worker 7, duration 31)
# 	Options for operation 10 (index 121): 1
# 		Option 1: Machine 1
# 			Worker options: 7
# 				(Worker 1, duration 44)
# 				(Worker 2, duration 51)
# 				(Worker 3, duration 47)
# 				(Worker 4, duration 51)
# 				(Worker 5, duration 43)
# 				(Worker 6, duration 50)
# 				(Worker 7, duration 45)
# 	Options for operation 11 (index 122): 1
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 4, duration 61)
# 	Options for operation 12 (index 123): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 3, duration 57)
# 				(Worker 4, duration 64)
# 				(Worker 7, duration 65)
# 	Options for operation 13 (index 124): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 1, duration 91)
# 				(Worker 2, duration 99)
# 				(Worker 3, duration 105)
# 				(Worker 6, duration 97)
# 				(Worker 7, duration 103)
# 	Options for operation 14 (index 125): 1
# 		Option 1: Machine 4
# 			Worker options: 2
# 				(Worker 5, duration 76)
# 				(Worker 6, duration 68)
# 	Options for operation 15 (index 126): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 5, duration 80)
# 	Options for operation 16 (index 127): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 2, duration 11)
# 				(Worker 3, duration 11)
# 				(Worker 4, duration 9)
# 				(Worker 5, duration 9)
# 				(Worker 6, duration 9)
# 	Options for operation 17 (index 128): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 1, duration 35)
# Total operations for job 8: 25
# 	Options for operation 1 (index 129): 1
# 		Option 1: Machine 3
# 			Worker options: 5
# 				(Worker 1, duration 58)
# 				(Worker 3, duration 59)
# 				(Worker 5, duration 55)
# 				(Worker 6, duration 56)
# 				(Worker 7, duration 60)
# 	Options for operation 2 (index 130): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 51)
# 				(Worker 3, duration 53)
# 				(Worker 4, duration 54)
# 				(Worker 5, duration 55)
# 				(Worker 7, duration 54)
# 	Options for operation 3 (index 131): 1
# 		Option 1: Machine 4
# 			Worker options: 7
# 				(Worker 1, duration 19)
# 				(Worker 2, duration 20)
# 				(Worker 3, duration 19)
# 				(Worker 4, duration 19)
# 				(Worker 5, duration 20)
# 				(Worker 6, duration 18)
# 				(Worker 7, duration 18)
# 	Options for operation 4 (index 132): 1
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 1, duration 54)
# 	Options for operation 5 (index 133): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 86)
# 				(Worker 2, duration 85)
# 				(Worker 4, duration 90)
# 				(Worker 5, duration 84)
# 				(Worker 6, duration 82)
# 				(Worker 7, duration 92)
# 	Options for operation 6 (index 134): 1
# 		Option 1: Machine 5
# 			Worker options: 4
# 				(Worker 1, duration 48)
# 				(Worker 3, duration 42)
# 				(Worker 5, duration 48)
# 				(Worker 6, duration 48)
# 	Options for operation 7 (index 135): 2
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 66)
# 				(Worker 2, duration 72)
# 				(Worker 3, duration 74)
# 				(Worker 4, duration 66)
# 				(Worker 5, duration 73)
# 				(Worker 6, duration 79)
# 				(Worker 7, duration 73)
# 		Option 2: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 79)
# 				(Worker 2, duration 75)
# 				(Worker 3, duration 76)
# 				(Worker 4, duration 73)
# 				(Worker 5, duration 77)
# 				(Worker 6, duration 80)
# 				(Worker 7, duration 73)
# 	Options for operation 8 (index 136): 2
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 2, duration 31)
# 				(Worker 4, duration 31)
# 				(Worker 5, duration 29)
# 				(Worker 6, duration 32)
# 				(Worker 7, duration 29)
# 		Option 2: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 30)
# 				(Worker 2, duration 29)
# 				(Worker 3, duration 33)
# 				(Worker 4, duration 27)
# 				(Worker 5, duration 31)
# 				(Worker 6, duration 30)
# 				(Worker 7, duration 33)
# 	Options for operation 9 (index 137): 1
# 		Option 1: Machine 2
# 			Worker options: 3
# 				(Worker 2, duration 45)
# 				(Worker 3, duration 45)
# 				(Worker 6, duration 45)
# 	Options for operation 10 (index 138): 1
# 		Option 1: Machine 2
# 			Worker options: 7
# 				(Worker 1, duration 47)
# 				(Worker 2, duration 51)
# 				(Worker 3, duration 50)
# 				(Worker 4, duration 51)
# 				(Worker 5, duration 53)
# 				(Worker 6, duration 52)
# 				(Worker 7, duration 52)
# 	Options for operation 11 (index 139): 1
# 		Option 1: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 37)
# 				(Worker 2, duration 34)
# 				(Worker 3, duration 37)
# 				(Worker 4, duration 39)
# 				(Worker 5, duration 36)
# 				(Worker 6, duration 35)
# 				(Worker 7, duration 37)
# 	Options for operation 12 (index 140): 1
# 		Option 1: Machine 2
# 			Worker options: 2
# 				(Worker 2, duration 78)
# 				(Worker 3, duration 75)
# 	Options for operation 13 (index 141): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 5, duration 37)
# 				(Worker 7, duration 36)
# 	Options for operation 14 (index 142): 1
# 		Option 1: Machine 1
# 			Worker options: 1
# 				(Worker 6, duration 70)
# 	Options for operation 15 (index 143): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 2, duration 64)
# 	Options for operation 16 (index 144): 1
# 		Option 1: Machine 4
# 			Worker options: 2
# 				(Worker 5, duration 36)
# 				(Worker 7, duration 40)
# 	Options for operation 17 (index 145): 2
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 2, duration 17)
# 				(Worker 7, duration 16)
# 		Option 2: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 15)
# 				(Worker 3, duration 16)
# 				(Worker 4, duration 16)
# 				(Worker 6, duration 15)
# 				(Worker 7, duration 17)
# 	Options for operation 18 (index 146): 1
# 		Option 1: Machine 4
# 			Worker options: 3
# 				(Worker 3, duration 30)
# 				(Worker 4, duration 32)
# 				(Worker 7, duration 28)
# 	Options for operation 19 (index 147): 1
# 		Option 1: Machine 4
# 			Worker options: 2
# 				(Worker 4, duration 40)
# 				(Worker 6, duration 39)
# 	Options for operation 20 (index 148): 1
# 		Option 1: Machine 1
# 			Worker options: 7
# 				(Worker 1, duration 88)
# 				(Worker 2, duration 102)
# 				(Worker 3, duration 85)
# 				(Worker 4, duration 87)
# 				(Worker 5, duration 88)
# 				(Worker 6, duration 85)
# 				(Worker 7, duration 91)
# 	Options for operation 21 (index 149): 1
# 		Option 1: Machine 5
# 			Worker options: 1
# 				(Worker 3, duration 57)
# 	Options for operation 22 (index 150): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 33)
# 				(Worker 2, duration 34)
# 				(Worker 3, duration 34)
# 				(Worker 4, duration 37)
# 				(Worker 7, duration 35)
# 	Options for operation 23 (index 151): 1
# 		Option 1: Machine 5
# 			Worker options: 3
# 				(Worker 1, duration 64)
# 				(Worker 3, duration 73)
# 				(Worker 5, duration 69)
# 	Options for operation 24 (index 152): 1
# 		Option 1: Machine 3
# 			Worker options: 4
# 				(Worker 1, duration 22)
# 				(Worker 3, duration 20)
# 				(Worker 6, duration 20)
# 				(Worker 7, duration 21)
# 	Options for operation 25 (index 153): 1
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 6, duration 23)
# Total operations for job 9: 23
# 	Options for operation 1 (index 154): 2
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 6, duration 62)
# 		Option 2: Machine 5
# 			Worker options: 3
# 				(Worker 1, duration 70)
# 				(Worker 4, duration 63)
# 				(Worker 6, duration 69)
# 	Options for operation 2 (index 155): 1
# 		Option 1: Machine 3
# 			Worker options: 7
# 				(Worker 1, duration 61)
# 				(Worker 2, duration 60)
# 				(Worker 3, duration 54)
# 				(Worker 4, duration 59)
# 				(Worker 5, duration 62)
# 				(Worker 6, duration 52)
# 				(Worker 7, duration 57)
# 	Options for operation 3 (index 156): 1
# 		Option 1: Machine 5
# 			Worker options: 5
# 				(Worker 1, duration 71)
# 				(Worker 2, duration 68)
# 				(Worker 3, duration 68)
# 				(Worker 4, duration 65)
# 				(Worker 6, duration 59)
# 	Options for operation 4 (index 157): 1
# 		Option 1: Machine 5
# 			Worker options: 2
# 				(Worker 3, duration 38)
# 				(Worker 4, duration 37)
# 	Options for operation 5 (index 158): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 1, duration 42)
# 				(Worker 2, duration 46)
# 	Options for operation 6 (index 159): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 3, duration 79)
# 				(Worker 7, duration 79)
# 	Options for operation 7 (index 160): 2
# 		Option 1: Machine 3
# 			Worker options: 1
# 				(Worker 7, duration 42)
# 		Option 2: Machine 4
# 			Worker options: 3
# 				(Worker 2, duration 41)
# 				(Worker 4, duration 46)
# 				(Worker 5, duration 42)
# 	Options for operation 8 (index 161): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 82)
# 				(Worker 2, duration 77)
# 				(Worker 3, duration 75)
# 				(Worker 5, duration 84)
# 				(Worker 6, duration 80)
# 				(Worker 7, duration 84)
# 	Options for operation 9 (index 162): 1
# 		Option 1: Machine 3
# 			Worker options: 4
# 				(Worker 1, duration 47)
# 				(Worker 4, duration 51)
# 				(Worker 6, duration 48)
# 				(Worker 7, duration 47)
# 	Options for operation 10 (index 163): 1
# 		Option 1: Machine 4
# 			Worker options: 7
# 				(Worker 1, duration 76)
# 				(Worker 2, duration 70)
# 				(Worker 3, duration 74)
# 				(Worker 4, duration 71)
# 				(Worker 5, duration 75)
# 				(Worker 6, duration 80)
# 				(Worker 7, duration 72)
# 	Options for operation 11 (index 164): 1
# 		Option 1: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 36)
# 				(Worker 2, duration 36)
# 				(Worker 3, duration 38)
# 				(Worker 4, duration 36)
# 				(Worker 5, duration 33)
# 				(Worker 6, duration 37)
# 				(Worker 7, duration 32)
# 	Options for operation 12 (index 165): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 75)
# 				(Worker 3, duration 78)
# 				(Worker 4, duration 74)
# 				(Worker 5, duration 73)
# 				(Worker 6, duration 78)
# 				(Worker 7, duration 71)
# 	Options for operation 13 (index 166): 1
# 		Option 1: Machine 2
# 			Worker options: 4
# 				(Worker 3, duration 47)
# 				(Worker 4, duration 45)
# 				(Worker 5, duration 45)
# 				(Worker 7, duration 47)
# 	Options for operation 14 (index 167): 1
# 		Option 1: Machine 3
# 			Worker options: 2
# 				(Worker 3, duration 80)
# 				(Worker 5, duration 84)
# 	Options for operation 15 (index 168): 2
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 42)
# 				(Worker 2, duration 42)
# 				(Worker 3, duration 43)
# 				(Worker 5, duration 39)
# 				(Worker 6, duration 38)
# 				(Worker 7, duration 40)
# 		Option 2: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 42)
# 				(Worker 2, duration 40)
# 				(Worker 3, duration 43)
# 				(Worker 4, duration 45)
# 				(Worker 5, duration 39)
# 				(Worker 6, duration 43)
# 				(Worker 7, duration 46)
# 	Options for operation 16 (index 169): 1
# 		Option 1: Machine 2
# 			Worker options: 4
# 				(Worker 1, duration 18)
# 				(Worker 3, duration 17)
# 				(Worker 4, duration 20)
# 				(Worker 5, duration 20)
# 	Options for operation 17 (index 170): 1
# 		Option 1: Machine 1
# 			Worker options: 6
# 				(Worker 1, duration 65)
# 				(Worker 2, duration 60)
# 				(Worker 3, duration 63)
# 				(Worker 4, duration 58)
# 				(Worker 5, duration 66)
# 				(Worker 6, duration 59)
# 	Options for operation 18 (index 171): 1
# 		Option 1: Machine 1
# 			Worker options: 3
# 				(Worker 1, duration 100)
# 				(Worker 3, duration 92)
# 				(Worker 6, duration 106)
# 	Options for operation 19 (index 172): 1
# 		Option 1: Machine 4
# 			Worker options: 3
# 				(Worker 4, duration 16)
# 				(Worker 5, duration 16)
# 				(Worker 6, duration 16)
# 	Options for operation 20 (index 173): 1
# 		Option 1: Machine 3
# 			Worker options: 5
# 				(Worker 1, duration 34)
# 				(Worker 2, duration 31)
# 				(Worker 5, duration 34)
# 				(Worker 6, duration 36)
# 				(Worker 7, duration 31)
# 	Options for operation 21 (index 174): 2
# 		Option 1: Machine 3
# 			Worker options: 7
# 				(Worker 1, duration 90)
# 				(Worker 2, duration 93)
# 				(Worker 3, duration 105)
# 				(Worker 4, duration 103)
# 				(Worker 5, duration 103)
# 				(Worker 6, duration 104)
# 				(Worker 7, duration 93)
# 		Option 2: Machine 4
# 			Worker options: 4
# 				(Worker 1, duration 90)
# 				(Worker 2, duration 106)
# 				(Worker 4, duration 89)
# 				(Worker 7, duration 99)
# 	Options for operation 22 (index 175): 1
# 		Option 1: Machine 5
# 			Worker options: 1
# 				(Worker 4, duration 82)
# 	Options for operation 23 (index 176): 1
# 		Option 1: Machine 1
# 			Worker options: 1
# 				(Worker 2, duration 50)
# Total operations for job 10: 19
# 	Options for operation 1 (index 177): 1
# 		Option 1: Machine 4
# 			Worker options: 5
# 				(Worker 1, duration 85)
# 				(Worker 2, duration 88)
# 				(Worker 4, duration 85)
# 				(Worker 5, duration 77)
# 				(Worker 6, duration 78)
# 	Options for operation 2 (index 178): 1
# 		Option 1: Machine 2
# 			Worker options: 1
# 				(Worker 5, duration 41)
# 	Options for operation 3 (index 179): 1
# 		Option 1: Machine 1
# 			Worker options: 4
# 				(Worker 1, duration 56)
# 				(Worker 2, duration 54)
# 				(Worker 6, duration 56)
# 				(Worker 7, duration 58)
# 	Options for operation 4 (index 180): 1
# 		Option 1: Machine 5
# 			Worker options: 2
# 				(Worker 3, duration 58)
# 				(Worker 7, duration 60)
# 	Options for operation 5 (index 181): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 32)
# 				(Worker 2, duration 29)
# 				(Worker 3, duration 27)
# 				(Worker 5, duration 30)
# 				(Worker 6, duration 30)
# 				(Worker 7, duration 30)
# 	Options for operation 6 (index 182): 1
# 		Option 1: Machine 5
# 			Worker options: 6
# 				(Worker 1, duration 55)
# 				(Worker 3, duration 57)
# 				(Worker 4, duration 57)
# 				(Worker 5, duration 62)
# 				(Worker 6, duration 54)
# 				(Worker 7, duration 65)
# 	Options for operation 7 (index 183): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 2, duration 47)
# 				(Worker 3, duration 54)
# 				(Worker 4, duration 50)
# 				(Worker 5, duration 53)
# 				(Worker 7, duration 55)
# 	Options for operation 8 (index 184): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 1, duration 88)
# 				(Worker 2, duration 97)
# 				(Worker 4, duration 100)
# 				(Worker 5, duration 97)
# 				(Worker 6, duration 86)
# 	Options for operation 9 (index 185): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 33)
# 				(Worker 2, duration 34)
# 				(Worker 3, duration 31)
# 				(Worker 5, duration 35)
# 				(Worker 6, duration 30)
# 				(Worker 7, duration 34)
# 	Options for operation 10 (index 186): 1
# 		Option 1: Machine 2
# 			Worker options: 6
# 				(Worker 1, duration 84)
# 				(Worker 2, duration 88)
# 				(Worker 4, duration 84)
# 				(Worker 5, duration 81)
# 				(Worker 6, duration 78)
# 				(Worker 7, duration 82)
# 	Options for operation 11 (index 187): 1
# 		Option 1: Machine 3
# 			Worker options: 6
# 				(Worker 1, duration 43)
# 				(Worker 3, duration 43)
# 				(Worker 4, duration 40)
# 				(Worker 5, duration 43)
# 				(Worker 6, duration 41)
# 				(Worker 7, duration 45)
# 	Options for operation 12 (index 188): 1
# 		Option 1: Machine 2
# 			Worker options: 5
# 				(Worker 1, duration 36)
# 				(Worker 2, duration 34)
# 				(Worker 3, duration 34)
# 				(Worker 6, duration 33)
# 				(Worker 7, duration 32)
# 	Options for operation 13 (index 189): 1
# 		Option 1: Machine 1
# 			Worker options: 5
# 				(Worker 1, duration 41)
# 				(Worker 2, duration 39)
# 				(Worker 4, duration 39)
# 				(Worker 5, duration 43)
# 				(Worker 6, duration 42)
# 	Options for operation 14 (index 190): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 72)
# 				(Worker 2, duration 87)
# 				(Worker 4, duration 86)
# 				(Worker 5, duration 75)
# 				(Worker 6, duration 77)
# 				(Worker 7, duration 87)
# 	Options for operation 15 (index 191): 1
# 		Option 1: Machine 1
# 			Worker options: 2
# 				(Worker 6, duration 79)
# 				(Worker 7, duration 79)
# 	Options for operation 16 (index 192): 1
# 		Option 1: Machine 4
# 			Worker options: 6
# 				(Worker 1, duration 69)
# 				(Worker 2, duration 60)
# 				(Worker 3, duration 68)
# 				(Worker 4, duration 68)
# 				(Worker 5, duration 67)
# 				(Worker 6, duration 68)
# 	Options for operation 17 (index 193): 1
# 		Option 1: Machine 5
# 			Worker options: 7
# 				(Worker 1, duration 81)
# 				(Worker 2, duration 71)
# 				(Worker 3, duration 72)
# 				(Worker 4, duration 78)
# 				(Worker 5, duration 79)
# 				(Worker 6, duration 80)
# 				(Worker 7, duration 72)
# 	Options for operation 18 (index 194): 1
# 		Option 1: Machine 3
# 			Worker options: 7
# 				(Worker 1, duration 21)
# 				(Worker 2, duration 24)
# 				(Worker 3, duration 25)
# 				(Worker 4, duration 25)
# 				(Worker 5, duration 23)
# 				(Worker 6, duration 21)
# 				(Worker 7, duration 24)
# 	Options for operation 19 (index 195): 1
# 		Option 1: Machine 4
# 			Worker options: 1
# 				(Worker 6, duration 54)

# %%
encoding.job_sequence().__len__()
# Out:
# 196

# %%
encoding.n_jobs()
# Out:
# 10

# %%
solver = GreedyFJSSPWSolver(encoding.durations(), encoding.job_sequence())
sequence, machines, workers = solver.solve()

# %%
import util.evaluation as evaluation
start_times, machines, workers = evaluation.translate(sequence, machines, workers, encoding.durations()) # necessary because the solver does not provide the start times of the schedule
c = evaluation.makespan(start_times, machines, workers, encoding.durations())

# %%
print(f'Makespan: {c}')
# Out:
# Makespan: 8180
